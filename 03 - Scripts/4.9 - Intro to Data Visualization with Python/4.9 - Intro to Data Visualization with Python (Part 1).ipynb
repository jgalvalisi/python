# %% [markdown]
# # 4.9 - Intro to Data Visualization with Python (Part 1)

# %% [markdown]
# ### This script contains the following points:
#
# * 01 - Importing Libraries
# * 02 - Importing Data
# * 03 - Wrangling Data
#     * a) Changing the Column Names
#     * b) Changing Data Types
#     * c) Dropping Columns + Transposing Data
# * 04 - Data Consistency
#     * a) Looking for Missing Values (NaN)
#     * b) Looking for Duplicates Records
#     * c) Looking for Mixed Data Types
# * 05 - Combining Dataframes
# * 06 - Exporting Data

# %% [markdown]
# ---

# %% [markdown]
# # 01 - Importing Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os
from datetime import datetime

# %% [markdown]
# ---

# %% [markdown]
# # 02 - Importing Data

# %%
# Define path

path = r'/Users/juanigalvalisi/01-07-2022 - Instacart Basket Analysis/'

# %% [markdown]
# ### Dataframe 1: orders_products_merged_v3.pkl

# %%
# Import orders_products_merged_v3.pkl

df_ords_prods = pd.read_pickle(os.path.join(path, '02 - Data', 'Prepared Data', 'orders_products_merged_v3.pkl'))

# %%
# Check the output of df_ords_prods

df_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_last_order  new_customer  Unnamed: 0  product_id  add_to_cart_order  \
# 0              NaN          True    24076664         196                  1
# 1             15.0         False    22742744         196                  1
# 2             21.0         False     4488095         196                  1
# 3             29.0         False    21376074         196                  1
# 4             28.0         False     4089398         196                  1
#
#    ...        price_range     busiest_day    busiest_days  \
# ...

# %%
# Check the output of df_ords_prods II

df_ords_prods.shape
# Out:
# (32404859, 26)

# %%
# Check the output of df_ords_prods III

df_ords_prods.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07        3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01        2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01        2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00        1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_last_order    Unnamed: 0    product_id  \
# count       3.240486e+07     3.032876e+07  3.240486e+07  3.240486e+07
# mean        1.342515e+01     1.110408e+01  1.621722e+07  2.559866e+04
# std         4.246380e+00     8.779064e+00  9.363013e+06  1.408400e+04
# min         0.000000e+00     0.000000e+00  0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# ### Dataframe 2: customers.csv

# %%
# Import customers.csv

df_custs = pd.read_csv(os.path.join(path, '02 - Data', 'Original Data', 'customers.csv'))

# %%
# Check the output of df_custs

df_custs.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# Check the output of df_custs II

df_custs.shape
# Out:
# (206209, 10)

# %%
# Check the output of df_custs III

df_custs.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# ---

# %% [markdown]
# # 03 - Data Wrangling

# %% [markdown]
# ### a) Changing the Column Names

# %%
# Change the column names

df_custs.columns
# Out:
# Index(['user_id', 'First Name', 'Surnam', 'Gender', 'STATE', 'Age',
#        'date_joined', 'n_dependants', 'fam_status', 'income'],
#       dtype='object')

# %%
columns2 = df_custs.rename(columns = {'First Name': 'first_name', 'Surnam': 'last_name', 'Gender': 'gender', 'STATE': 'state', 'Age': 'age', 'n_dependants': 'number_of_dependants', 'fam_status': 'marital_status'}, inplace = True)

# %%
# Check the output

df_custs.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependants marital_status  income
# 0                     3        married  165665
# 1                     0         single   59285
# 2                     2        married   99568
# 3                     0         single   42049
# 4                     1        married   40374

# %%
# Check the output II

df_custs.shape

# %% [markdown]
# ### b) Changing Data Types

# %% [markdown]
# #### 1) df_ords_prods

# %%
# Check all the data types of df_ords_prods

df_ords_prods.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# order_number                int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_last_order           float64
# new_customer                 bool
# Unnamed: 0                  int64
# product_id                  int64
# add_to_cart_order           int64
# reordered                   int64
# product_name               object
# aisle_id                    int64
# department_id               int64
# prices                    float64
# outlier_prices             object
# price_range                object
# busiest_day                object
# busiest_days               object
# busiest_period_of_day      object
# max_order                   int64
# loyalty_flag               object
# mean_user_spending        float64
# spender_flag               object
# order_frequency_median    float64
# order_frequency_flag       object
# dtype: object

# %%
# Change the 'user_id' variable from int64 to string

df_ords_prods['user_id'] = df_ords_prods['user_id'].astype('str')

# %% [markdown]
# #### 2) df_custs

# %%
# Check all the data types of df_custs

df_custs.dtypes
# Out:
# user_id                  int64
# first_name              object
# last_name               object
# gender                  object
# state                   object
# age                      int64
# date_joined             object
# number_of_dependants     int64
# marital_status          object
# income                   int64
# dtype: object

# %%
# Change the 'user_id' variable from int64 to string

df_custs['user_id'] = df_custs['user_id'].astype('str')

# %%
# Change the 'age' variable from int64 to int8

df_custs['age'] = df_custs['age'].astype('int8')

# %%
# Change the 'number_of_dependants' variable from int64 to int16

df_custs['number_of_dependants'] = df_custs['number_of_dependants'].astype('int16')

# %%
# Change the 'income' variable from int64 to int32

df_custs['income'] = df_custs['income'].astype('int32')

# %%
# Change the 'data_joined' variable from int64 to datatime

df_custs['date_joined'] = df_custs['date_joined'].astype('str')

# %%
# Check the output

df_custs.dtypes
# Out:
# user_id                 object
# first_name              object
# last_name               object
# gender                  object
# state                   object
# age                      int16
# date_joined             object
# number_of_dependants     int32
# marital_status          object
# income                   int64
# dtype: object

# %% [markdown]
# ### c) Dropping Columns + Transposing Data

# %%
# Delete unnecesary columns due to memory saving

df_ords_prods = df_ords_prods.drop(columns = ['aisle_id', 'Unnamed: 0', 'busiest_days'])

# %% [markdown]
# ---

# %% [markdown]
# # 04 - Data Consistency

# %%
# Check df_custs numerical variables

df_custs.describe()
# Out:
#                  age  number_of_dependants         income
# count  206209.000000         206209.000000  206209.000000
# mean       49.501646              1.499823   94632.852548
# std        18.480962              1.118433   42473.786988
# min        18.000000              0.000000   25903.000000
# 25%        33.000000              0.000000   59874.000000
# 50%        49.000000              1.000000   93547.000000
# 75%        66.000000              3.000000  124244.000000
# max        81.000000              3.000000  593901.000000

# %% [markdown]
# > #### The dataframe appears to be consistent. The maximum revenue value might be an outlier, but, at the same time, it might also be conceivable.

# %% [markdown]
# ### a) Looking for Missing Values (NaN)

# %%
# Look for missing values (NaN)

df_custs.isnull().sum()
# Out:
# user_id                     0
# first_name              11259
# last_name                   0
# gender                      0
# state                       0
# age                         0
# date_joined                 0
# number_of_dependants        0
# marital_status              0
# income                      0
# dtype: int64

# %%
# Check NaN values within 'first_name' column

df_custs[df_custs['first_name'].isnull() == True]
# Out:
#        user_id first_name last_name  gender         state  age date_joined  \
# 53       76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73       13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82       89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99       96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105      29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...        ...        ...       ...     ...           ...  ...         ...
# 206038  121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044  200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090  167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162  187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171  116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         number_of_dependants marital_status  income
# ...

# %% [markdown]
# > #### We will maintain these missing values because they are still relevant information, and we can supplement them with the gender information, which has no missing values. In this case, beyond this lack of information, we can know if this customer is a male or female.

# %% [markdown]
# ### b) Looking for Duplicates Records

# %%
# Look for duplicates

df_dups = df_custs[df_custs.duplicated()]

# %%
# Check the output

df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, number_of_dependants, marital_status, income]
# Index: []

# %% [markdown]
# > #### There are no duplicates values.

# %% [markdown]
# ### c) Looking for Mixed Data Types

# %%
# Check for mixed types

for col in df_custs.columns.tolist():
  weird = (df_custs[[col]].applymap(type) != df_custs[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_custs[weird]) > 0:
    print (col)
# Out:
# first_name

# %%
# Fix the 'first_name' column mixed types

df_custs['first_name'] = df_custs['first_name'].astype('str')

# %%
# Check the output

for col in df_custs.columns.tolist():
  weird = (df_custs[[col]].applymap(type) != df_custs[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_custs[weird]) > 0:
    print (col)

# %% [markdown]
# ---

# %% [markdown]
# # 05 - Combining Dataframes

# %%
# Look for a common column in df_ords_prods

df_ords_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 23 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 object
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_last_order         float64
#  6   new_customer            bool
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  product_name            object
#  11  department_id           int64
#  12  prices                  float64
#  13  outlier_prices          object
#  14  price_range             object
#  15  busiest_day             object
#  16  busiest_period_of_day   object
#  17  max_order               int64
#  18  loyalty_flag            object
#  19  mean_user_spending      float64
#  20  spender_flag            object
# ...

# %%
# Look for a common column in df_custs

df_custs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               206209 non-null  object
#  1   first_name            206209 non-null  object
#  2   last_name             206209 non-null  object
#  3   gender                206209 non-null  object
#  4   state                 206209 non-null  object
#  5   age                   206209 non-null  int16
#  6   date_joined           206209 non-null  object
#  7   number_of_dependants  206209 non-null  int32
#  8   marital_status        206209 non-null  object
#  9   income                206209 non-null  int64
# dtypes: int16(1), int32(1), int64(1), object(7)
# memory usage: 13.8+ MB

# %%
# Join df_ords_prods + df_custs with 'user_id' as a column key

df_merged = df_ords_prods.merge(df_custs, on = 'user_id')

# %%
# Check the output

df_merged.head()
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
#
#    days_last_order  new_customer  product_id  add_to_cart_order  reordered  \
# 0              NaN          True         196                  1          0
# 1             15.0         False         196                  1          1
# 2             21.0         False         196                  1          1
# 3             29.0         False         196                  1          1
# 4             28.0         False         196                  1          1
#
# ...

# %%
# Check the output II

df_merged.shape
# Out:
# (32404859, 32)

# %% [markdown]
# ---

# %% [markdown]
# # 06 - Exporting Data

# %%
# Export df_custs as .pkl

df_custs.to_pickle(os.path.join(path, '02 - Data', 'Prepared Data', 'customers_checked.pkl'))

# %%
# Export combined dataframes as .pkl

df_merged.to_pickle(os.path.join(path, '02 - Data', 'Prepared Data', 'orders_products_customers_merged.pkl'))

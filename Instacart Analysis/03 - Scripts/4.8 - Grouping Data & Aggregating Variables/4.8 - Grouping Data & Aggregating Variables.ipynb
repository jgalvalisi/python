# %% [markdown]
# # 4.8 - Grouping Data & Aggregating Variables

# %% [markdown]
# ### This script contains the following points:
#
# * 01 - Importing Libraries
# * 02 - Importing Data
# * 03 - Grouping and Aggregating Data
# * 04 - Creating a Loyalty Flag
# * 05 - Creating a Spender Flag
# * 06 - Creating a Frequency Flag
# * 07 -  Exporting Data

# %% [markdown]
# ---

# %% [markdown]
# ## 01 - Importing Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ---

# %% [markdown]
# ## 02 - Importing Data

# %%
# Define path

path = r'/Users/juanigalvalisi/01-07-2022 - Instacart Basket Analysis/'

# %%
# Import .PKL

df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 - Data', 'Prepared Data', 'orders_products_merged_v2.pkl'))

# %%
# Check the output of df_ords_prods_merge

df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_last_order  new_customer  Unnamed: 0  product_id  add_to_cart_order  \
# 0              NaN          True    24076664         196                  1
# 1             15.0         False    22742744         196                  1
# 2             21.0         False     4488095         196                  1
# 3             29.0         False    21376074         196                  1
# 4             28.0         False     4089398         196                  1
#
#    reordered product_name  aisle_id  department_id  prices outlier_prices  \
# 0          0         Soda        77              7     9.0    Not Outlier
# 1          1         Soda        77              7     9.0    Not Outlier
# 2          1         Soda        77              7     9.0    Not Outlier
# 3          1         Soda        77              7     9.0    Not Outlier
# 4          1         Soda        77              7     9.0    Not Outlier
#
#          price_range     busiest_day    busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Regularly busy        Average orders
# 1  Mid-range product  Regularly busy  Regularly busy        Average orders
# 2  Mid-range product  Regularly busy  Regularly busy           Most orders
# 3  Mid-range product      Least busy      Least busy        Average orders
# 4  Mid-range product      Least busy      Least busy           Most orders

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 20)

# %%
# Ignore maximum of rows

pd.options.display.max_rows = None

# %% [markdown]
# ---

# %% [markdown]
# ## 03 - Grouping and Aggregating Data

# %%
# Perform Multiple Aggregations

df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %%
# Compare the full data frame with a one million rows subset

df_subset = df_ords_prods_merge[:1000000]
df_subset.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# > **We now have all of our 21 departments as opposed to the subset where we only had 7. Moreover, all the means are higher with the subset than the entire data frame, ranging from 11,29 to 19,46 and 15,21 to 22,90, respectively.**

# %% [markdown]
# ---

# %% [markdown]
# ## 04 - Creating a Loyalty Flag

# %%
# Create a loyalty flag for existing customers using the transform() and loc() functions

df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check the output

df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_last_order  new_customer  Unnamed: 0  product_id  add_to_cart_order  \
# 0              NaN          True    24076664         196                  1
# 1             15.0         False    22742744         196                  1
# 2             21.0         False     4488095         196                  1
# 3             29.0         False    21376074         196                  1
# 4             28.0         False     4089398         196                  1
#
#    ...  product_name aisle_id  department_id  prices  outlier_prices  \
# 0  ...          Soda       77              7     9.0     Not Outlier
# 1  ...          Soda       77              7     9.0     Not Outlier
# 2  ...          Soda       77              7     9.0     Not Outlier
# 3  ...          Soda       77              7     9.0     Not Outlier
# 4  ...          Soda       77              7     9.0     Not Outlier
#
#          price_range     busiest_day    busiest_days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy  Regularly busy        Average orders
# 1  Mid-range product  Regularly busy  Regularly busy        Average orders
# 2  Mid-range product  Regularly busy  Regularly busy           Most orders
# 3  Mid-range product      Least busy      Least busy        Average orders
# 4  Mid-range product      Least busy      Least busy           Most orders
#
#   max_order
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#
# [5 rows x 21 columns]

# %%
# Establish flag criteria I

df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal Customer'

# %%
# Establish flag criteria II

df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular Customer'

# %%
# Establish flag criteria III

df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New Customer'

# %%
# Check the frequency of the new column, 'loyalty_flag'

df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular Customer    15876776
# Loyal Customer      10284093
# New Customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Check the final output

df_ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_last_order  new_customer  Unnamed: 0  product_id  add_to_cart_order  \
# 0              NaN          True    24076664         196                  1
# 1             15.0         False    22742744         196                  1
# 2             21.0         False     4488095         196                  1
# 3             29.0         False    21376074         196                  1
# 4             28.0         False     4089398         196                  1
# 5             19.0         False    31927070         196                  1
# 6             20.0         False     5212927         196                  1
# 7             14.0         False    29474806         196                  2
# 8              0.0         False    21760446         196                  4
# 9             30.0         False    24181266         196                  1
#
#    ...  aisle_id department_id  prices  outlier_prices        price_range  \
# 0  ...        77             7     9.0     Not Outlier  Mid-range product
# 1  ...        77             7     9.0     Not Outlier  Mid-range product
# 2  ...        77             7     9.0     Not Outlier  Mid-range product
# 3  ...        77             7     9.0     Not Outlier  Mid-range product
# 4  ...        77             7     9.0     Not Outlier  Mid-range product
# 5  ...        77             7     9.0     Not Outlier  Mid-range product
# 6  ...        77             7     9.0     Not Outlier  Mid-range product
# 7  ...        77             7     9.0     Not Outlier  Mid-range product
# 8  ...        77             7     9.0     Not Outlier  Mid-range product
# 9  ...        77             7     9.0     Not Outlier  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy  Regularly busy        Average orders        10
# 1  Regularly busy  Regularly busy        Average orders        10
# 2  Regularly busy  Regularly busy           Most orders        10
# 3      Least busy      Least busy        Average orders        10
# 4      Least busy      Least busy           Most orders        10
# 5  Regularly busy  Regularly busy        Average orders        10
# 6  Regularly busy  Regularly busy           Most orders        10
# 7  Regularly busy  Regularly busy           Most orders        10
# 8  Regularly busy  Regularly busy           Most orders        10
# 9      Least busy      Least busy        Average orders        10
#
#    loyalty_flag
# 0  New Customer
# 1  New Customer
# 2  New Customer
# 3  New Customer
# 4  New Customer
# 5  New Customer
# 6  New Customer
# 7  New Customer
# 8  New Customer
# 9  New Customer
#
# [10 rows x 22 columns]

# %%
# Check the final output II

df_ords_prods_merge.shape
# Out:
# (32404859, 22)

# %%
# Check the basic statistics of the product prices for each new loyalty category

df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal Customer    7.774457  1.0  25.0
# New Customer      7.802354  1.0  25.0
# Regular Customer  7.799319  1.0  25.0

# %% [markdown]
# > **As we can see, loyal customers buy the least expensive products, while the new customers acquire, on average, the most expensive products. Regular customers maintain in the middle, but near only a difference of 0,80 from the new customers.**

# %% [markdown]
# ---

# %% [markdown]
# ## 05 - Creating a Spender Flag

# %%
# Create a new column for average prices for each user

df_ords_prods_merge['mean_user_spending'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check the output

df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_last_order  new_customer  Unnamed: 0  product_id  add_to_cart_order  \
# 0              NaN          True    24076664         196                  1
# 1             15.0         False    22742744         196                  1
# 2             21.0         False     4488095         196                  1
# 3             29.0         False    21376074         196                  1
# 4             28.0         False     4089398         196                  1
#
#    ...  department_id prices  outlier_prices        price_range  \
# 0  ...              7    9.0     Not Outlier  Mid-range product
# 1  ...              7    9.0     Not Outlier  Mid-range product
# 2  ...              7    9.0     Not Outlier  Mid-range product
# 3  ...              7    9.0     Not Outlier  Mid-range product
# 4  ...              7    9.0     Not Outlier  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day max_order  \
# 0  Regularly busy  Regularly busy        Average orders        10
# 1  Regularly busy  Regularly busy        Average orders        10
# 2  Regularly busy  Regularly busy           Most orders        10
# 3      Least busy      Least busy        Average orders        10
# 4      Least busy      Least busy           Most orders        10
#
#    loyalty_flag mean_user_spending
# 0  New Customer           6.367797
# 1  New Customer           6.367797
# 2  New Customer           6.367797
# 3  New Customer           6.367797
# 4  New Customer           6.367797
#
# [5 rows x 23 columns]

# %%
# Establish flag criteria

df_ords_prods_merge.loc[df_ords_prods_merge['mean_user_spending'] < 10, 'spender_flag'] = 'Low Spender'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['mean_user_spending'] >= 10, 'spender_flag'] = 'High Spender'

# %%
# Check the frequency of the new column, 'spender_flag'

df_ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# Low Spender     32284898
# High Spender      119961
# Name: spender_flag, dtype: int64

# %%
# Check the final output

df_ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_last_order  new_customer  Unnamed: 0  product_id  add_to_cart_order  \
# 0              NaN          True    24076664         196                  1
# 1             15.0         False    22742744         196                  1
# 2             21.0         False     4488095         196                  1
# 3             29.0         False    21376074         196                  1
# 4             28.0         False     4089398         196                  1
# 5             19.0         False    31927070         196                  1
# 6             20.0         False     5212927         196                  1
# 7             14.0         False    29474806         196                  2
# 8              0.0         False    21760446         196                  4
# 9             30.0         False    24181266         196                  1
#
#    ...  prices outlier_prices        price_range     busiest_day  \
# 0  ...     9.0    Not Outlier  Mid-range product  Regularly busy
# 1  ...     9.0    Not Outlier  Mid-range product  Regularly busy
# 2  ...     9.0    Not Outlier  Mid-range product  Regularly busy
# 3  ...     9.0    Not Outlier  Mid-range product      Least busy
# 4  ...     9.0    Not Outlier  Mid-range product      Least busy
# 5  ...     9.0    Not Outlier  Mid-range product  Regularly busy
# 6  ...     9.0    Not Outlier  Mid-range product  Regularly busy
# 7  ...     9.0    Not Outlier  Mid-range product  Regularly busy
# 8  ...     9.0    Not Outlier  Mid-range product  Regularly busy
# 9  ...     9.0    Not Outlier  Mid-range product      Least busy
#
#      busiest_days busiest_period_of_day max_order  loyalty_flag  \
# 0  Regularly busy        Average orders        10  New Customer
# 1  Regularly busy        Average orders        10  New Customer
# 2  Regularly busy           Most orders        10  New Customer
# 3      Least busy        Average orders        10  New Customer
# 4      Least busy           Most orders        10  New Customer
# 5  Regularly busy        Average orders        10  New Customer
# 6  Regularly busy           Most orders        10  New Customer
# 7  Regularly busy           Most orders        10  New Customer
# 8  Regularly busy           Most orders        10  New Customer
# 9      Least busy        Average orders        10  New Customer
#
#   mean_user_spending spender_flag
# 0           6.367797  Low Spender
# 1           6.367797  Low Spender
# 2           6.367797  Low Spender
# 3           6.367797  Low Spender
# 4           6.367797  Low Spender
# 5           6.367797  Low Spender
# 6           6.367797  Low Spender
# 7           6.367797  Low Spender
# 8           6.367797  Low Spender
# 9           6.367797  Low Spender
#
# [10 rows x 24 columns]

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 24)

# %% [markdown]
# > **In general terms, loyal customers buy the least expensive products, while the new customers adquire, on average, the most expensive products. Regular customers maintain in the middle, but near from only a difference of 0,80 from the new customers.**

# %% [markdown]
# ---

# %% [markdown]
# ## 06 - Creating a Frequency Flag

# %%
# Create an order frequency flag that marks the regularity of a user’s ordering
# behavior according to the median in the “days_last_order” column

df_ords_prods_merge['order_frequency_median'] = df_ords_prods_merge.groupby(['user_id'])['days_last_order'].transform(np.median)

# %%
# Check the output

df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_last_order  new_customer  Unnamed: 0  product_id  add_to_cart_order  \
# 0              NaN          True    24076664         196                  1
# 1             15.0         False    22742744         196                  1
# 2             21.0         False     4488095         196                  1
# 3             29.0         False    21376074         196                  1
# 4             28.0         False     4089398         196                  1
#
#    ...  outlier_prices        price_range     busiest_day    busiest_days  \
# 0  ...     Not Outlier  Mid-range product  Regularly busy  Regularly busy
# 1  ...     Not Outlier  Mid-range product  Regularly busy  Regularly busy
# 2  ...     Not Outlier  Mid-range product  Regularly busy  Regularly busy
# 3  ...     Not Outlier  Mid-range product      Least busy      Least busy
# 4  ...     Not Outlier  Mid-range product      Least busy      Least busy
#
#    busiest_period_of_day max_order  loyalty_flag mean_user_spending  \
# 0         Average orders        10  New Customer           6.367797
# 1         Average orders        10  New Customer           6.367797
# 2            Most orders        10  New Customer           6.367797
# 3         Average orders        10  New Customer           6.367797
# 4            Most orders        10  New Customer           6.367797
#
#   spender_flag order_frequency_median
# 0  Low Spender                   20.5
# 1  Low Spender                   20.5
# 2  Low Spender                   20.5
# 3  Low Spender                   20.5
# 4  Low Spender                   20.5
#
# [5 rows x 25 columns]

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 25)

# %%
# Establish flag criteria

df_ords_prods_merge.loc[df_ords_prods_merge['days_last_order'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['days_last_order']  > 10) & (df_ords_prods_merge['days_last_order'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['days_last_order'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Check the frequency of the new column, 'order_frequency_flag'

df_ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        19042466
# Regular customer          6055803
# Non-frequent customer     5230494
# NaN                       2076096
# Name: order_frequency_flag, dtype: int64

# %%
# Check the output

df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_last_order  new_customer  Unnamed: 0  product_id  add_to_cart_order  \
# 0              NaN          True    24076664         196                  1
# 1             15.0         False    22742744         196                  1
# 2             21.0         False     4488095         196                  1
# 3             29.0         False    21376074         196                  1
# 4             28.0         False     4089398         196                  1
#
#    ...        price_range     busiest_day    busiest_days  \
# 0  ...  Mid-range product  Regularly busy  Regularly busy
# 1  ...  Mid-range product  Regularly busy  Regularly busy
# 2  ...  Mid-range product  Regularly busy  Regularly busy
# 3  ...  Mid-range product      Least busy      Least busy
# 4  ...  Mid-range product      Least busy      Least busy
#
#    busiest_period_of_day  max_order  loyalty_flag mean_user_spending  \
# 0         Average orders         10  New Customer           6.367797
# 1         Average orders         10  New Customer           6.367797
# 2            Most orders         10  New Customer           6.367797
# 3         Average orders         10  New Customer           6.367797
# 4            Most orders         10  New Customer           6.367797
#
#   spender_flag order_frequency_median   order_frequency_flag
# 0  Low Spender                   20.5                    NaN
# 1  Low Spender                   20.5       Regular customer
# 2  Low Spender                   20.5  Non-frequent customer
# 3  Low Spender                   20.5  Non-frequent customer
# 4  Low Spender                   20.5  Non-frequent customer
#
# [5 rows x 26 columns]

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 26)

# %% [markdown]
# > **Frequent customers made almost 60% of the orders. At the same time, the NaN values display the number of purchases made by customers who did buy something only once in their history as customers in Instacart.**

# %% [markdown]
# ---

# %% [markdown]
# ## 07- Exporting Data

# %%
# Export .pkl data frame

df_ords_prods_merge.to_pickle(os.path.join(path, '02 - Data', 'Prepared Data', 'orders_products_merged_v3.pkl'))
